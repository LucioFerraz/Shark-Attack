# %%
#Plano de negócio sobre shark attack. 
#Com base nos dados apresentados pelo arquivo CSV, após os devidos tratamentos, será realizada uma business question, que 
#irei responder com base nas informações trazidas pela base e análise. Código fonte e apresentação a parte. 
#Primeiro passo: Import Pandas Lib, Seaborn (lib visualização de dados) e Numpy.

# %%
#como salvar uma imagem no jupyther notebook.
#salvar imagem no mesmo local.
#passar a célula para markdown
#![texto](shark.jpg)

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Segundo passo: Read the file 'attacks.csv' e atribuição a DataFrame.
df = pd.read_csv('Dataset_shark_attacks.csv', sep=',')
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
#Visualização head do arquivo. 
pd.read_csv('attacks.csv').head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson�McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
#verificação do tamanho do arquivo. 
len(df)
# Out:
# 25723

# %%
#verificação de descrições, dados do arquivo csv. 
df.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#verificação das últimas linhas, no qual nota-se a presença de muitos nans. 
df.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 25718  ...      NaN                    NaN  NaN          NaN  NaN
# 25719  ...      NaN                    NaN  NaN          NaN  NaN
# 25720  ...      NaN                    NaN  NaN          NaN  NaN
# 25721  ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# ...

# %%
#df.info() para conhecer a estrutura dos meus dados, saber os Dtype e fazer estimativas.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
#df.columns para saber o nome das colunas.
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#df.drop para eliminar as colunas não necessárias a minha análise e manipulação de dados. 
df.drop(columns=['Case Number', 'Name', 'Age','Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'Unnamed: 22', 'Unnamed: 23'], inplace=True)

# %%
#len(df.columns) para verificar número de colunas, nesse caso, foram delatadas 10 colunas e restaram 13 para análise. 
len(df.columns)
# Out:
# 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            6302 non-null   object
#  1   Year            6300 non-null   float64
#  2   Type            6298 non-null   object
#  3   Country         6252 non-null   object
#  4   Area            5847 non-null   object
#  5   Location        5762 non-null   object
#  6   Activity        5758 non-null   object
#  7   Sex             5737 non-null   object
#  8   Injury          6274 non-null   object
#  9   Fatal (Y/N)     5763 non-null   object
#  10  Time            2948 non-null   object
#  11  Species         3464 non-null   object
#  12  original order  6309 non-null   float64
# dtypes: float64(2), object(11)
# memory usage: 2.6+ MB

# %%
#função value_counts() para agregar os grupos da coluna selecionada e mostrar a incidencia de casos de ataque.
df.Country.value_counts()
# Out:
# USA                               2229
# AUSTRALIA                         1338
# SOUTH AFRICA                       579
# PAPUA NEW GUINEA                   134
# NEW ZEALAND                        128
#                                   ...
# BRITISH ISLES                        1
# GULF OF ADEN                         1
# FEDERATED STATES OF MICRONESIA       1
# NORTHERN MARIANA ISLANDS             1
# REUNION ISLAND                       1
# Name: Country, Length: 212, dtype: int64

# %%
#com essa função percebe-se que de todos os paises que constam no csv os precentuais de ataques por paises.
#ordenação por chaves conforme incidencia. 
df.Country.value_counts(normalize=True).head(5)
# Out:
# USA                 0.356526
# AUSTRALIA           0.214012
# SOUTH AFRICA        0.092610
# PAPUA NEW GUINEA    0.021433
# NEW ZEALAND         0.020473
# Name: Country, dtype: float64

# %%
df
# Out:
#               Date    Year        Type    Country             Area  \
# 0      25-Jun-2018  2018.0     Boating        USA       California
# 1      18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2      09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3      08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4      04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...            ...     ...         ...        ...              ...
# 25718          NaN     NaN         NaN        NaN              NaN
# 25719          NaN     NaN         NaN        NaN              NaN
# 25720          NaN     NaN         NaN        NaN              NaN
# 25721          NaN     NaN         NaN        NaN              NaN
# 25722          NaN     NaN         NaN        NaN              NaN
#
#                              Location     Activity Sex   \
# 0         Oceanside, San Diego County     Paddling    F
# ...

# %%
#type é registro.
df.groupby(['Country', 'Area']).count().sort_values('Type', ascending=False).head(10)[['Type']]
# Out:
#                                     Type
# Country      Area
# USA          Florida                1037
# AUSTRALIA    New South Wales         486
#              Queensland              311
# USA          Hawaii                  298
#              California              290
# SOUTH AFRICA KwaZulu-Natal           213
#              Western Cape Province   195
# AUSTRALIA    Western Australia       189
# SOUTH AFRICA Eastern Cape Province   160
# USA          South Carolina          159

# %%
df.groupby(['Country', 'Area']).mean().sort_values('Year', ascending=False).head(10)
# Out:
#                                         Year  original order
# Country    Area
# MALDIVES   Alifu Alifu Atoll     2018.000000     6280.000000
# THAILAND   Hua Hin               2018.000000     6281.500000
# BRAZIL     Boi Island, Victoria  2018.000000     6259.000000
# BAHAMAS    New Providence        2018.000000     6273.000000
# BRAZIL     Fernando de Noronha   2018.000000     6252.000000
# ENGLAND    Cornwall              2018.000000     6290.000000
# COSTA RICA Cocos Island          2017.333333     6258.666667
# AUSTRALIA  Westerm Australia     2017.333333     6240.333333
# BAHAMAS    Great Exuma           2017.000000     6132.000000
# REUNION    Saint-Andre           2017.000000     6129.000000

# %%
#mascara utilizada para selecionar somente a info que necessita do DF. 
Year_2018=df.Year==2018
df[Year_2018]

#ou df[df.Year==2018]
# Out:
#                     Date    Year          Type        Country  \
# 0            25-Jun-2018  2018.0       Boating            USA
# 1            18-Jun-2018  2018.0    Unprovoked            USA
# 2            09-Jun-2018  2018.0       Invalid            USA
# 3            08-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 4            04-Jun-2018  2018.0      Provoked         MEXICO
# 5            03-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 6            03-Jun-2018  2018.0    Unprovoked         BRAZIL
# 7            27-May-2018  2018.0    Unprovoked            USA
# 8            26-May-2018  2018.0    Unprovoked            USA
# 9            26-May-2018  2018.0    Unprovoked            USA
# 10           24-May-2018  2018.0      Provoked      AUSTRALIA
# 11           21-May-2018  2018.0    Unprovoked            USA
# 12           13-May-2018  2018.0    Unprovoked            USA
# 13           13-May-2018  2018.0       Invalid        ENGLAND
# ...

# %%
#Máscara utilizada para selecionar apenas o dado necessários, assim, cria-se nova coluna, baseada nesse argumento.
df[df.Country == 'USA']
# Out:
#                     Date    Year        Type Country             Area  \
# 0            25-Jun-2018  2018.0     Boating     USA       California
# 1            18-Jun-2018  2018.0  Unprovoked     USA          Georgia
# 2            09-Jun-2018  2018.0     Invalid     USA           Hawaii
# 7            27-May-2018  2018.0  Unprovoked     USA          Florida
# 8            26-May-2018  2018.0  Unprovoked     USA          Florida
# ...                  ...     ...         ...     ...              ...
# 6249         Before 1958     0.0  Unprovoked     USA          Florida
# 6283         Before 1921     0.0  Unprovoked     USA          Florida
# 6288  Before 17-Jul-1916     0.0  Unprovoked     USA  North Carolina
# 6292          Circa 1862     0.0  Unprovoked     USA           Hawaii
# 6299           1900-1905     0.0  Unprovoked     USA   North Carolina
#
#                                                Location  Activity Sex   \
# ...

# %%
#innerjoin interseção de elementos (pertence em grupo A e B, por exemplo, relativo a chave escolhida)
#leftjoin todo o grupo A + intersenção de elementos com B, por exemplo, relativo a chave escolhida.
#rightjoin todo o grupo B + interseção de elementos com A, por exemplo, relativo a chave escolhida.
#fullouterjoin todo o grupo A e B e interseção de elementos.

# %%
#cut  mesmo espaço, mas numero de argumentos distintos. Posso separa em grupos, criar nova coluna, relacionar duas colunas e atribuir media.
#qcut espaços diferentes, mas com numero de argumentos iguais. 
pd.cut(df.Year, bins=4)/ df['year_interval'] = pd.cut(df.Year, bins=4) /df.groupby('year_interval')['CO2 Emission Grams/Mile'].mean()
pd.qcut (df.Year, q=2).value_counts(normalize=True)

# %%
#data cleaning, divide-se em tres esferas, conversão de tipos, valores nulos e duplicados.

# %%
df.isnull()
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 25718         True   True   True   True     True   True      True      True
# 25719         True   True   True   True     True   True      True      True
# 25720         True   True   True   True     True   True      True      True
# 25721         True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
# ...

# %%
#soma dos nulos na direção da coluna. Dada uma coluna indica numero de nulos desta.
#Qual a coluna com maior numero de nulos?
df.isnull().sum(axis=0)
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
#soma dos nulos na direção da coluna em ordem decrescente.
df.isnull().sum(axis=0).sort_values(ascending=False)
# Out:
# Unnamed: 22               25722
# Unnamed: 23               25721
# Time                      22775
# Species                   22259
# Age                       22252
# Sex                       19986
# Activity                  19965
# Location                  19961
# Fatal (Y/N)               19960
# Area                      19876
# Name                      19631
# Country                   19471
# Injury                    19449
# Investigator or Source    19438
# Type                      19425
# Year                      19423
# href formula              19422
# Date                      19421
# pdf                       19421
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Case Number               17021
# dtype: int64

# %%
#consigo analisar o percentual de nulos por coluna. 
((df.isnull().sum(axis=0))/len(df)).sort_values(ascending=False)
# Out:
# Unnamed: 22               0.999961
# Unnamed: 23               0.999922
# Time                      0.885394
# Species                   0.865335
# Age                       0.865062
# Sex                       0.776970
# Activity                  0.776154
# Location                  0.775998
# Fatal (Y/N)               0.775959
# Area                      0.772694
# Name                      0.763169
# Country                   0.756949
# Injury                    0.756094
# Investigator or Source    0.755666
# Type                      0.755161
# Year                      0.755083
# href formula              0.755044
# Date                      0.755005
# pdf                       0.755005
# href                      0.755005
# Case Number.1             0.755005
# Case Number.2             0.755005
# original order            0.754733
# Case Number               0.661704
# dtype: float64

# %%
#soma dos nulos na direção da linha. Ou seja, em 25722 linhas, tenho para cada uma o n. de nulos descrito a frente.
df.isnull().sum(axis=1)
# Out:
# 0         2
# 1         3
# 2         3
# 3         4
# 4         4
#          ..
# 25718    24
# 25719    24
# 25720    24
# 25721    24
# 25722    23
# Length: 25723, dtype: int64

# %%
#verificar o mair numero de registros nulos por linha.
df.isnull().sum(axis=1).sort_values(ascending=False).head(10)
# Out:
# 12861    24
# 11352    24
# 11338    24
# 11339    24
# 11340    24
# 11341    24
# 11342    24
# 11343    24
# 11344    24
# 11345    24
# dtype: int64

# %%
#proporção de registros nulos para cada registro. Cada um dos valores / pelo numero de colunas. 
(df.isnull().sum(axis=1)/len(df.columns)).sort_values(ascending=False)
# Out:
# 12861    1.000000
# 11352    1.000000
# 11338    1.000000
# 11339    1.000000
# 11340    1.000000
#            ...
# 3046     0.083333
# 1386     0.083333
# 1387     0.083333
# 1388     0.083333
# 0        0.083333
# Length: 25723, dtype: float64

# %%
#Heatmap, por meio do sns, ha possibilidade de visualizar os dados. Quando é bege(nulo), quando é preto(nao nulo). 
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
#Preciso deletar as colunas com mais nulos, para depois aplicar o dropna, senao, zero todo DF por ter nulos em todas as linhas.
#thresh estipulo um percentual de nao nulos para exclusao da coluna
df6 = df.dropna(thresh=10)
df6
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sns.heatmap(df6.isnull())
# Out:
# <AxesSubplot:>

# %%
list(df6['Species '].unique())
# Out:
# ['White shark',
#  nan,
#  '2 m shark',
#  'Tiger shark, 3m',
#  'Tiger shark',
#  "Lemon shark, 3'",
#  "Bull shark, 6'",
#  'Grey reef shark',
#  'Invalid incident',
#  'Tawny nurse shark, 2m',
#  'Shark involvement not confirmed',
#  'Questionable',
#  '3 m shark',
#  'White shark, 3.5 m',
#  'White shark, 2.5 m',
#  "6' shark",
#  'Juvenile bull shark',
#  'Bull shark',
#  "Tiger shark, 12'",
#  'Wobbegong shark',
#  '3.5 m shark',
#  '1.8 m shark',
#  'Blacktip shark',
#  'Juvenile white shark,  2.7 to 3.2 m',
#  'Bull shark, 2 m',
#  'Possibly a wobbegong',
#  'Injury believed caused by an eel, not a shark',
#  'Galapagos shark?',
#  '2m shark',
#  'Bull shark, 3 m ',
#  'Grey reef shark. 2 m',
#  'small shark',
#  'Wobbegong shark?',
#  'Juvenile nurse shark',
#  "Nurse shark. 5'",
#  'Tiger shark, female',
#  'Some drowned but other may have been killed by blue sharks',
#  'White shark, 4.6 m',
#  'Cookiecutter shark',
#  'Wobbegong shark, 1 m',
#  'White shark, 4.5 m',
# ...

# %%
def tubarao_branco(x):
    try: 
        if 'white shark' in x.lower():
            return 'white shark'
        else: 
            return x 
    except: 
        return x

# %%
#Condição (exemplo): 
'white shark' in 'White shark, 2.5 m'.lower()
# Out:
# True

# %%
df6['Species ']
# Out:
# 0           White shark
# 1                   NaN
# 2                   NaN
# 3             2 m shark
# 4       Tiger shark, 3m
#              ...
# 6297                NaN
# 6298                NaN
# 6299                NaN
# 6300                NaN
# 6301                NaN
# Name: Species , Length: 6302, dtype: object

# %%
#especies aplicar função
df6['white_shark']=df6['Species '].apply(tubarao_branco)
# Out:
# <ipython-input-16-54d423c2d0d0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['white_shark']=df6['Species '].apply(tubarao_branco)

# %%
df6
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
df7 = df6[df6['white_shark']=='white shark']
df7
# Out:
#        Case Number                     Date    Year        Type       Country  \
# 0       2018.06.25              25-Jun-2018  2018.0     Boating           USA
# 22      2018.04.24              24-Apr-2018  2018.0  Unprovoked     AUSTRALIA
# 24      2018.04.22              22-Apr-2018  2018.0  Unprovoked  SOUTH AFRICA
# 34      2018.04.03              03-Apr-2018  2018.0  Unprovoked  SOUTH AFRICA
# 40      2018.02.23              23-Feb-2018  2018.0  Unprovoked     AUSTRALIA
# ...            ...                      ...     ...         ...           ...
# 6162  1700.00.00.b                    1700s  1700.0  Unprovoked        FRANCE
# 6172    1554.00.00                 Ca. 1554  1554.0  Unprovoked        FRANCE
# 6244       ND.0062              Before 1960     0.0  Unprovoked       BAHAMAS
# 6245       ND.0060      Before  19-Jun-1959     0.0  Unprovoked           USA
# 6274       ND.0028  A few years before 1938     0.0        Boat         ITALY
#
# ...

# %%
df8 = df7.groupby(['Country', 'Area']).count().sort_values('Species ', ascending=False)[['Species ']].rename(columns={'Species ':'Contador'}).reset_index()

# %%
df8
# Out:
#          Country                   Area  Contador
# 0            USA             California       156
# 1   SOUTH AFRICA  Western Cape Province       103
# 2      AUSTRALIA        South Australia        41
# 3      AUSTRALIA      Western Australia        41
# 4      AUSTRALIA        New South Wales        38
# ..           ...                    ...       ...
# 84         MALTA         St. Thomas Bay         1
# 85    MONTENEGRO           Adriatic Sea         1
# 86    MOZAMBIQUE                   Gaza         1
# 87   NEW ZEALAND        Antarctic Ocean         1
# 88         JAPAN       Aichi Prefecture         1
#
# [89 rows x 3 columns]

# %%
df9 = df8[df8['Country']=='USA']
# Out:
#    Country            Area  Contador
# 0      USA      California       156
# 7      USA          Oregon        22
# 14     USA  North Carolina         5
# 15     USA   Massachusetts         4
# 16     USA  South Carolina         4
# 19     USA         Florida         4
# 20     USA          Hawaii         3
# 23     USA      New Jersey         3
# 29     USA      Washington         2

# %%
#tipo de grafico. nao para esse caso. 
sns.histplot(df8)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
#heatmap sem incedencia de nulos.
sns.heatmap(df8.isnull())
# Out:
# <AxesSubplot:>

# %%
#tentar plotar um grafico
plt.figure(figsize=(20, 6), dpi=60)
sns.barplot(x=df_Country.head(4).index, y=shark_attack_counter)

# %%
# função cumsum, encarregada de fazer uma soma cumulativa.
